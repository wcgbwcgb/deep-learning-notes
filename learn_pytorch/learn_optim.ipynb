# %%
from torch.utils.data import DataLoader
import torchvision
from torch.nn import Sequential, Conv2d, MaxPool2d, Flatten, Linear
from torch import nn
import torch

dataset = torchvision.datasets.CIFAR10("./CIFAR10_dataset", train=False, transform=torchvision.transforms.ToTensor(),
                                       download=True)
dataloader = DataLoader(dataset, batch_size=1, drop_last=True)

class CIFARModel(nn.Module):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.model1 = Sequential(
            Conv2d(3, 32, 5, padding=2),
            MaxPool2d(2),
            Conv2d(32, 32, 5, padding=2),
            MaxPool2d(2),
            Conv2d(32, 64, 5, padding=2),
            MaxPool2d(2),
            Flatten(),
            Linear(1024, 64),
            Linear(64, 10)
        )

    def forward(self, x):
        x = self.model1(x)
        return x
    
model_CIFAR = CIFARModel()
loss = nn.CrossEntropyLoss()

optim = torch.optim.SGD(model_CIFAR.parameters(), lr=0.01, )
for epoch in range(20):
    running_loss = 0.0
    for data in dataloader:  # one round of learning
        imgs, targets = data
        output = model_CIFAR(imgs)
        result_loss = loss(output, targets)
        optim.zero_grad()
        result_loss.backward()
        optim.step()
        running_loss = running_loss + result_loss
    print(running_loss)
# Out:
# tensor(18734.1367, grad_fn=<AddBackward0>)
# tensor(16186.0430, grad_fn=<AddBackward0>)
# tensor(15438.5479, grad_fn=<AddBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 42
#      40     optim.zero_grad()
#      41     result_loss.backward()
# ---> 42     optim.step()
#      43     running_loss = running_loss + result_loss
#      44 print(running_loss)
#
# File d:\deep-learning-notes\venv\lib\site-packages\torch\optim\optimizer.py:502, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     500 self = cast(Optimizer, self)
#     501 profile_name = f"Optimizer.step#{self.__class__.__name__}.step"
# --> 502 with torch.autograd.profiler.record_function(profile_name):
#     503     # call optimizer step pre hooks
#     504     for pre_hook in chain(
#     505         _global_optimizer_pre_hooks.values(),
# ...
