# %% [markdown]
# ## Orthogonalization
# one to one mapping between target and tools
#
# Chain of assumptions in ML:
# 1. fit training set well --> human-level performance
# 2. fit dev set well
# 3. fit test set well
# 4. perform well in real world
